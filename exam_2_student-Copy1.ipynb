# %% [markdown]
# # Exam R
# Mark Klik & Misja Mikkers
#
# # Introduction
#
# Before you turn this problem in, make sure everything runs as expected. First, **restart the kernel** (in the menubar, select Kernel$\rightarrow$Restart) and then **run all cells** (in the menubar, select Cell$\rightarrow$Run All).
#
# Make sure you fill in any place that says `YOUR CODE HERE` or "YOUR ANSWER HERE", as well as your name and collaborators below:

# %%
NAME = "Camilla Christensen, #2008949#, #u476647#"
COLLABORATORS = ""

# %% [markdown]
# Fill in the cell above to provide us with your name and student number, like
#
# NAME = "Adam Smith, #student number#"
#
# where you replace "#student number#" with your ... (very good!)
#
# Unfortunately, you are not allowed to work with "COLLABORATORS" in this exam.
#
# ## exam September 21th, 2018
#
# With this R part of the exam you can earn at max. 4 points.
#
# In the first cell of the notebook, give us your name and student number in the way indicated above.
#
# Fill in the notebook (see below for code cells and text cells that you need to fill in).
#
# If you look at the menus above (File, Edit, View etc.), there is one called "Cell". If you click on this, you can change the "Cell Type". Choose "Code" when you are typing python or R code. Choose "Markdown" when you are typing, well, markdown.
#
# When you finish the notebook, make sure that you save it with the output of your code included.
#
# Then put it on github, e.g. by dragging it onto github (see instructions below).
#
# Finally, add a link to your README file with the name of this exam: "Exam R September 7, 2018".
#
# # Packages
#
# You will need the following packages for this exam.

# %%
library(tidyverse)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.2.1 ──
# ✔ ggplot2 2.2.1     ✔ purrr   0.2.4
# ✔ tibble  1.4.1     ✔ dplyr   0.7.4
# ✔ tidyr   0.7.2     ✔ stringr 1.2.0
# ✔ readr   1.1.1     ✔ forcats 0.2.0
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %% [markdown]
# # Assignment 1
#
# ## Data
#
# Please read in "Medicaid.csv" and check the structure.
#
# If needed change the variables Recipients and Total_costs into a numeric variable.
#
# Hint: don't forget you cannot change a factor in a numeric variable directly!

# %%
Medicaid <- read.csv2('Medicaid.csv')
str(Medicaid)
head(Medicaid)
# Out:
# 'data.frame':	13 obs. of  3 variables:
#  $ Year       : int  2003 2004 2005 2006 2007 2008 2009 2010 2011 2012 ...
#  $ Recipients : int  4267573 4594667 4733617 4730167 4622782 4657242 4911408 5212444 5398722 5598237 ...
#  $ Total_costs: num  3.61e+10 3.89e+10 4.08e+10 4.07e+10 4.21e+10 ...
#   Year Recipients Total_costs
# 1 2003 4267573    36142075737
# 2 2004 4594667    38926018824
# 3 2005 4733617    40803778540
# 4 2006 4730167    40712547369
# 5 2007 4622782    42127412366
# 6 2008 4657242    44239141758

# %%
Medicaid$Year_numeric <- as.numeric(Medicaid$Year)
Medicaid$Recipients_numeric <- as.numeric(Medicaid$Recipients)

str(Medicaid)
# Out:
# 'data.frame':	13 obs. of  5 variables:
#  $ Year              : int  2003 2004 2005 2006 2007 2008 2009 2010 2011 2012 ...
#  $ Recipients        : int  4267573 4594667 4733617 4730167 4622782 4657242 4911408 5212444 5398722 5598237 ...
#  $ Total_costs       : num  3.61e+10 3.89e+10 4.08e+10 4.07e+10 4.21e+10 ...
#  $ Year_numeric      : num  2003 2004 2005 2006 2007 ...
#  $ Recipients_numeric: num  4267573 4594667 4733617 4730167 4622782 ...

# %% [markdown]
# *As we can see in the first part of my code, year and recipients are integers, not numeric variables. I have changed the variables into numerics which could be done at once since they were not factors. When I check the structure of the data now, these variables are indeed numeric.*

# %% [markdown]
# ## New variable
#
# You will now have to make a new variable called "Cost_per_Recipient" by dividing the variable "Total_Costs" by the variable "Recipients". You will have to use the "pipe-operator". You have to show the "head" of the dataframe.

# %% [markdown]
# *First I define Cost_per_Recipient. By using mutate here, I add Cost_per_recipient to the dataframe. Because I changed Year and Recipients to numerics earlier, these are also in my dataframe.*

# %%
Cost_Per_Recipient <- Medicaid2$Total_costs / Medicaid2$Recipients_numeric


Medicaid2 <- Medicaid %>%
 mutate(Cost_Per_Recipient)

head(Medicaid2)
# Out:
#   Year Recipients Total_costs Year_numeric Recipients_numeric
# 1 2003 4267573    36142075737 2003         4267573
# 2 2004 4594667    38926018824 2004         4594667
# 3 2005 4733617    40803778540 2005         4733617
# 4 2006 4730167    40712547369 2006         4730167
# 5 2007 4622782    42127412366 2007         4622782
# 6 2008 4657242    44239141758 2008         4657242
#   Cost_Per_Recipient
# 1 8469
# 2 8472
# 3 8620
# 4 8607
# 5 9113
# 6 9499

# %% [markdown]
# ## Plot 1
#
# Now you have to make a line plot of the data:
#
# * with Year on the x-axis
# * Cost_per_Recipient on the y-axis
# * The line should have size 3 and the color "red"
# * The name on the Y axis should be "Cost per enrollee"

# %% [markdown]
# *ggplot makes a plot of medicaid2 (which includes numerics and cost_per_recipient) for me with year on x-axis and cost_per_recipient on the vertical axis
# I used geom_line to get a line in my plot using color and size to set these to red and 3
# Then I added geom_point() which adds the black dots that you can see. These are the dots through which the red line is created
# and lastly I have added the names Year and Cost per enrollee to my axes.
# I also tried to add geom_smooth() to see if my line would look prettier instead of this squary kinda look, but then I was suddenly getting error messages that Medicaid2 did not exist.*

# %%
ggplot(data = Medicaid2, aes(x=Year, y=Cost_Per_Recipient)) + 
    geom_line(color="red", size=3) + 
    geom_point() +
    xlab('Year') + 
    ylab('Cost per enrollee')
# Out:
# plot without title

# %% [markdown]
# End of notebook
